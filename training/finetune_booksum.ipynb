# %% [markdown]
# ## Installation

# %%
# !pip install 'sagemaker' 'transformers' 'datasets[s3]' 's3fs' --upgrade --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# awscli 1.22.97 requires botocore==1.24.42, but you have botocore 1.23.24 which is incompatible.

# %% [markdown]
# ## Environment set-up

# %%
import ast
import botocore
import os
import pandas as pd
import sagemaker
import sagemaker.huggingface

from datasets import Dataset
from datasets.filesystems import S3FileSystem
from sagemaker.huggingface import HuggingFace
from transformers import AutoTokenizer

# %% [markdown]
# ## AWS permissions

# %%
sess = sagemaker.Session()
sagemaker_session_bucket = None
if sagemaker_session_bucket is None and sess is not None:
    sagemaker_session_bucket = sess.default_bucket()

role = sagemaker.get_execution_role()
sess = sagemaker.Session(default_bucket=sagemaker_session_bucket)

print(f'Role ARN: {role}')
print(f'Bucket: {sess.default_bucket()}')
print(f'Region: {sess.boto_region_name}')
# Out:
# Role ARN: arn:aws:iam::583579242701:role/sagemaker
# Bucket: sagemaker-us-east-1-583579242701
# Region: us-east-1

# %% [markdown]
# ## Pre-processing

# %%
# Model/tokenizer checkpoint
CHECKPOINT = 'sshleifer/distilbart-cnn-12-6'

# Data directory
DATA_DIR = './data/'

# S3 key prefix for the data
S3_PREFIX = 'datasets'

# %%
def get_prefix(checkpoint):
    """Returns a prefix to be prepended to the input text."""
    if 't5' in checkpoint:
        return 'summarize: '
    else:
        return ''
    
def load_paragraph_dataset(split):
    """Loads a paragraph-level dataset for a specific split."""
    file_path = os.path.join(DATA_DIR, split + '.csv')
    df = pd.read_csv(file_path)
    df = df[['text', 'summary']]
    df['summary'] = df['summary'].apply(lambda row: ' '.join(ast.literal_eval(row)))
    dataset = Dataset.from_pandas(df)
    return dataset
    
def preprocess_batch(batch):
    """Preprocesses a batch of inputs for fine-tuning."""
    inputs = [prefix + text for text in batch['text']]
    model_inputs = tokenizer(inputs, max_length=1024, truncation=True)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(batch['summary'], max_length=512, truncation=True)
    model_inputs['labels'] = labels['input_ids']
    return model_inputs

def preprocess(dataset):
    """Preprocesses a dataset for fine-tuning."""
    dataset = dataset.map(preprocess_batch, batched=True)
    dataset = dataset.remove_columns(['text', 'summary'])
    return dataset

# %%
# Download tokenizer
tokenizer = AutoTokenizer.from_pretrained(CHECKPOINT)
prefix = get_prefix(CHECKPOINT)

# Load datasets
train_dataset = load_paragraph_dataset('train')
valid_dataset = load_paragraph_dataset('valid')

# Preprocessing
train_dataset = preprocess(train_dataset)
valid_dataset = preprocess(valid_dataset)
# Out:
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
#   0%|          | 0/117 [00:00<?, ?ba/s]
#   0%|          | 0/16 [00:00<?, ?ba/s]

# %% [markdown]
# ### Upload the data to `sagemaker_session_bucket`

# %%
s3 = S3FileSystem()

# Save the train dataset to S3
train_input_path = f's3://{sess.default_bucket()}/{S3_PREFIX}/train'
train_dataset.save_to_disk(train_input_path, fs=s3)

# Save the valid dataset to S3
valid_input_path = f's3://{sess.default_bucket()}/{S3_PREFIX}/valid'
valid_dataset.save_to_disk(valid_input_path, fs=s3)

# %% [markdown]
# ## Fine-tuning job

# %%
# !pygmentize ./scripts/finetune_booksum.py
# Out:
# import random
# import logging
# import sys
# import argparse
# import os
# import torch
#
# from datasets import Dataset, load_from_disk, load_metric
# from functools import partial
# from transformers import (
#     AutoTokenizer,
#     BartForConditionalGeneration,
#     PegasusForConditionalGeneration,
#     T5ForConditionalGeneration,
#     Seq2SeqTrainer,
#     Seq2SeqTrainingArguments,
#     DataCollatorForSeq2Seq
# )
#
#
# def load_pretrained_model(model_name):
#     """Loads a pre-trained conditional generation model from the Huggingface hub."""
#     if 'bart' in model_name:
#         return BartForConditionalGeneration.from_pretrained(model_name)
#     elif 'pegasus' in model_name:
#         return PegasusForConditionalGeneration.from_pretrained(model_name)
#     elif 't5' in model_name:
#         return T5ForConditionalGeneration.from_pretrained(model_name)
#     else:
#         raise ValueError(f'Model {model_name} is not supported.')
#
#
# if __name__ == '__main__':
#
#     parser = argparse.ArgumentParser()
#
#     # Hyperparameters passed as command-line arguments to the script
#     parser.add_argument('--epochs', type=int, default=3)
#     parser.add_argument('--train_batch_size', type=int, default=32)
#     parser.add_argument('--eval_batch_size', type=int, default=64)
#     parser.add_argument('--warmup_steps', type=int, default=500)
#     parser.add_argument('--model_name', type=str)
#     parser.add_argument('--learning_rate', type=str, default=2.0e-5)
#
#     # Huggingface hub arguments
#     parser.add_argument("--push_to_hub", type=bool, default=True)
#     parser.add_argument("--hub_model_id", type=str, default=None)
#     parser.add_argument("--hub_strategy", type=str, default=None)
#     parser.add_argument("--hub_token", type=str, default=None)
#
#
#     # Data, model, and output directories
#     parser.add_argument('--output_data_dir', type=str, default=os.environ['SM_OUTPUT_DATA_DIR'])
#     parser.add_argument('--model_dir', type=str, default=os.environ['SM_MODEL_DIR'])
#     parser.add_argument('--n_gpus', type=str, default=os.environ['SM_NUM_GPUS'])
#     parser.add_argument('--train_dir', type=str, default=os.environ['SM_CHANNEL_TRAIN'])
#     parser.add_argument('--valid_dir', type=str, default=os.environ['SM_CHANNEL_VALID'])
#
#     args, _ = parser.parse_known_args()
#
#     # Logging
#     logger = logging.getLogger(__name__)
#
#     logging.basicConfig(
#         level=logging.getLevelName("INFO"),
#         handlers=[logging.StreamHandler(sys.stdout)],
#         format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
#     )
#
#     # Load datasets
#     logger.info('Loading datasets...')
#     train_dataset = load_from_disk(args.train_dir)
#     valid_dataset = load_from_disk(args.valid_dir)
#
#     # Download model from model hub
#     logger.info(f'Loading {args.model_name} model...')
#     model = load_pretrained_model(args.model_name)
#     tokenizer = AutoTokenizer.from_pretrained(args.model_name)
#     data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
#
#     # Define training args
#     training_args = Seq2SeqTrainingArguments(
#         output_dir=args.model_dir,
#         num_train_epochs=args.epochs,
#         per_device_train_batch_size=args.train_batch_size,
#         per_device_eval_batch_size=args.eval_batch_size,
#         warmup_steps=args.warmup_steps,
#         evaluation_strategy='epoch',
#         logging_dir=f'{args.output_data_dir}/logs',
#         learning_rate=float(args.learning_rate),
#         push_to_hub=args.push_to_hub,
#         hub_strategy=args.hub_strategy,
#         hub_model_id=args.hub_model_id,
#         hub_token=args.hub_token,
#     )
#
#     # Create Trainer instance
#     trainer = Seq2SeqTrainer(
#         model=model,
#         args=training_args,
#         train_dataset=train_dataset,
#         eval_dataset=valid_dataset,
#         tokenizer=tokenizer,
#         data_collator=data_collator,
#     )
#
#     # Train model
#     logger.info('Fine-tuning the model...')
#     trainer.train()
#
#     # Push the model to the Huggingface hub
#     logger.info('Saving the model...')
#     trainer.create_model_card(model_name=args.hub_model_id)
#     trainer.push_to_hub(commit_message='Training complete')

# %% [markdown]
# ### Create an Estimator and start a training job

# %%
# Hyperparameters passed into the training job
hyperparameters={
    'model_name': 'sshleifer/distilbart-cnn-12-6',
    'train_batch_size': 4,
    'eval_batch_size': 8,
    'epochs': 2,
    'push_to_hub': True,
    'hub_model_id': 'distilbart-cnn-12-6-booksum',
    'hub_strategy': 'every_save',
    'hub_token': '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'
}

# %%
# Create the HF estimator
hf_estimator = HuggingFace(
    entry_point='./scripts/finetune_booksum.py',
    source_dir="./",
    instance_type='ml.g5.xlarge',
    instance_count=1,
    role=role,
    transformers_version='4.17.0',
    pytorch_version='1.10.2',
    py_version='py38',
    hyperparameters=hyperparameters,
)

# %%
# Run the training job
hf_estimator.fit({'train': train_input_path, 'valid': valid_input_path})
# Out:
# 2022-07-04 21:22:32 Starting - Starting the training job...
# 2022-07-04 21:22:56 Starting - Preparing the instances for trainingProfilerReport-1656969752: InProgress
# ......
# 2022-07-04 21:24:02 Downloading - Downloading input data...
# 2022-07-04 21:24:32 Training - Downloading the training image........................
# 2022-07-04 21:28:24 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# /opt/conda/lib/python3.8/site-packages/paramiko/transport.py:236: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# 2022-07-04 21:28:26,808 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-07-04 21:28:26,828 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-07-04 21:28:26,836 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-07-04 21:28:28,627 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "train": "/opt/ml/input/data/train",
#         "valid": "/opt/ml/input/data/valid"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "epochs": 2,
#         "eval_batch_size": 8,
#         "hub_model_id": "distilbart-cnn-12-6-booksum",
#         "hub_strategy": "every_save",
#         "hub_token": "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",
#         "model_name": "sshleifer/distilbart-cnn-12-6",
#         "push_to_hub": true,
#         "train_batch_size": 4
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "train": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "valid": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "huggingface-pytorch-training-2022-07-04-21-22-16-684",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-583579242701/huggingface-pytorch-training-2022-07-04-21-22-16-684/source/sourcedir.tar.gz",
#     "module_name": "./scripts/tune_booksum",
#     "network_interface_name": "eth0",
#     "num_cpus": 4,
#     "num_gpus": 1,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.g5.xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.g5.xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "./scripts/tune_booksum.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"epochs":2,"eval_batch_size":8,"hub_model_id":"distilbart-cnn-12-6-booksum","hub_strategy":"every_save","hub_token":"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","model_name":"sshleifer/distilbart-cnn-12-6","push_to_hub":true,"train_batch_size":4}
# SM_USER_ENTRY_POINT=./scripts/tune_booksum.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"valid":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["train","valid"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=./scripts/tune_booksum
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=4
# SM_NUM_GPUS=1
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-583579242701/huggingface-pytorch-training-2022-07-04-21-22-16-684/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"train":"/opt/ml/input/data/train","valid":"/opt/ml/input/data/valid"},"current_host":"algo-1","framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"epochs":2,"eval_batch_size":8,"hub_model_id":"distilbart-cnn-12-6-booksum","hub_strategy":"every_save","hub_token":"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","model_name":"sshleifer/distilbart-cnn-12-6","push_to_hub":true,"train_batch_size":4},"input_config_dir":"/opt/ml/input/config","input_data_config":{"train":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"valid":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"huggingface-pytorch-training-2022-07-04-21-22-16-684","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-583579242701/huggingface-pytorch-training-2022-07-04-21-22-16-684/source/sourcedir.tar.gz","module_name":"./scripts/tune_booksum","network_interface_name":"eth0","num_cpus":4,"num_gpus":1,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.g5.xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.g5.xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"./scripts/tune_booksum.py"}
# SM_USER_ARGS=["--epochs","2","--eval_batch_size","8","--hub_model_id","distilbart-cnn-12-6-booksum","--hub_strategy","every_save","--hub_token","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","--model_name","sshleifer/distilbart-cnn-12-6","--push_to_hub","True","--train_batch_size","4"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAIN=/opt/ml/input/data/train
# SM_CHANNEL_VALID=/opt/ml/input/data/valid
# SM_HP_EPOCHS=2
# SM_HP_EVAL_BATCH_SIZE=8
# SM_HP_HUB_MODEL_ID=distilbart-cnn-12-6-booksum
# SM_HP_HUB_STRATEGY=every_save
# SM_HP_HUB_TOKEN=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
# SM_HP_MODEL_NAME=sshleifer/distilbart-cnn-12-6
# SM_HP_PUSH_TO_HUB=true
# SM_HP_TRAIN_BATCH_SIZE=4
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python38.zip:/opt/conda/lib/python3.8:/opt/conda/lib/python3.8/lib-dynload:/opt/conda/lib/python3.8/site-packages:/opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220512-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/opt/conda/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# /opt/conda/bin/python3.8 ./scripts/tune_booksum.py --epochs 2 --eval_batch_size 8 --hub_model_id distilbart-cnn-12-6-booksum --hub_strategy every_save --hub_token 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 --model_name sshleifer/distilbart-cnn-12-6 --push_to_hub True --train_batch_size 4
# 2022-07-04 21:28:33,994 - __main__ - INFO - Loading datasets...
# 2022-07-04 21:28:34,017 - __main__ - INFO - Loading sshleifer/distilbart-cnn-12-6 model...
# Downloading:   0%|          | 0.00/1.76k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 1.76k/1.76k [00:00<00:00, 2.02MB/s]
# Downloading:   0%|          | 0.00/1.14G [00:00<?, ?B/s]
# Downloading:   1%|          | 7.21M/1.14G [00:00<00:16, 75.6MB/s]
# Downloading:   1%|          | 14.5M/1.14G [00:00<00:15, 76.1MB/s]
# Downloading:   2%|▏         | 21.8M/1.14G [00:00<00:15, 76.4MB/s]
# Downloading:   2%|▏         | 29.1M/1.14G [00:00<00:15, 75.6MB/s]
# Downloading:   3%|▎         | 36.3M/1.14G [00:00<00:15, 75.2MB/s]
# Downloading:   4%|▍         | 43.9M/1.14G [00:00<00:15, 76.8MB/s]
# Downloading:   4%|▍         | 51.4M/1.14G [00:00<00:15, 77.3MB/s]
# Downloading:   5%|▌         | 58.8M/1.14G [00:00<00:15, 75.0MB/s]
# Downloading:   6%|▌         | 66.6M/1.14G [00:00<00:14, 77.1MB/s]
# Downloading:   6%|▋         | 74.2M/1.14G [00:01<00:14, 78.0MB/s]
# Downloading:   7%|▋         | 81.7M/1.14G [00:01<00:15, 75.6MB/s]
# Downloading:   8%|▊         | 90.1M/1.14G [00:01<00:14, 79.3MB/s]
# Downloading:   8%|▊         | 98.2M/1.14G [00:01<00:13, 81.0MB/s]
# Downloading:   9%|▉         | 106M/1.14G [00:01<00:13, 81.1MB/s]
# Downloading:  10%|▉         | 115M/1.14G [00:01<00:13, 83.8MB/s]
# Downloading:  11%|█         | 123M/1.14G [00:01<00:13, 83.9MB/s]
# Downloading:  11%|█         | 131M/1.14G [00:01<00:12, 83.9MB/s]
# Downloading:  12%|█▏        | 139M/1.14G [00:01<00:13, 82.8MB/s]
# Downloading:  13%|█▎        | 147M/1.14G [00:01<00:12, 85.7MB/s]
# Downloading:  13%|█▎        | 156M/1.14G [00:02<00:12, 85.2MB/s]
# Downloading:  14%|█▍        | 165M/1.14G [00:02<00:11, 88.3MB/s]
# Downloading:  15%|█▍        | 173M/1.14G [00:02<00:12, 86.3MB/s]
# Downloading:  16%|█▌        | 181M/1.14G [00:02<00:12, 85.7MB/s]
# Downloading:  16%|█▋        | 190M/1.14G [00:02<00:12, 84.2MB/s]
# Downloading:  17%|█▋        | 198M/1.14G [00:02<00:12, 83.6MB/s]
# Downloading:  18%|█▊        | 206M/1.14G [00:02<00:12, 80.6MB/s]
# Downloading:  18%|█▊        | 213M/1.14G [00:02<00:12, 78.5MB/s]
# Downloading:  19%|█▉        | 221M/1.14G [00:02<00:12, 78.1MB/s]
# Downloading:  70%|██████▉   | 813M/1.14G [00:10<00:05, 72.1MB/s]
# Downloading:  70%|███████   | 821M/1.14G [00:10<00:05, 72.3MB/s]
# Downloading:  71%|███████   | 828M/1.14G [00:10<00:04, 71.6MB/s]
# Downloading:  72%|███████▏  | 835M/1.14G [00:10<00:04, 72.3MB/s]
# Downloading:  72%|███████▏  | 842M/1.14G [00:10<00:04, 71.8MB/s]
# Downloading:  73%|███████▎  | 850M/1.14G [00:10<00:04, 74.9MB/s]
# Downloading:  74%|███████▎  | 857M/1.14G [00:11<00:04, 76.6MB/s]
# Downloading:  74%|███████▍  | 865M/1.14G [00:11<00:04, 76.9MB/s]
# Downloading:  75%|███████▍  | 872M/1.14G [00:11<00:04, 75.2MB/s]
# Downloading:  75%|███████▌  | 880M/1.14G [00:11<00:03, 76.2MB/s]
# Downloading:  76%|███████▌  | 887M/1.14G [00:11<00:03, 76.9MB/s]
# Downloading:  77%|███████▋  | 894M/1.14G [00:11<00:03, 76.9MB/s]
# Downloading:  77%|███████▋  | 902M/1.14G [00:11<00:03, 76.2MB/s]
# Downloading:  78%|███████▊  | 909M/1.14G [00:11<00:03, 77.7MB/s]
# Downloading:  79%|███████▊  | 917M/1.14G [00:11<00:03, 77.3MB/s]
# Downloading:  79%|███████▉  | 924M/1.14G [00:11<00:03, 74.7MB/s]
# Downloading:  80%|███████▉  | 931M/1.14G [00:12<00:03, 73.7MB/s]
# Downloading:  81%|████████  | 938M/1.14G [00:12<00:03, 73.3MB/s]
# Downloading:  81%|████████  | 945M/1.14G [00:12<00:03, 72.4MB/s]
# Downloading:  82%|████████▏ | 953M/1.14G [00:12<00:02, 74.8MB/s]
# Downloading:  82%|████████▏ | 960M/1.14G [00:12<00:02, 74.3MB/s]
# Downloading:  83%|████████▎ | 968M/1.14G [00:12<00:02, 76.3MB/s]
# Downloading:  84%|████████▎ | 976M/1.14G [00:12<00:02, 78.0MB/s]
# Downloading:  84%|████████▍ | 983M/1.14G [00:12<00:02, 76.5MB/s]
# Downloading:  85%|████████▍ | 991M/1.14G [00:12<00:02, 75.5MB/s]
# Downloading:  86%|████████▌ | 998M/1.14G [00:12<00:02, 74.0MB/s]
# Downloading:  86%|████████▌ | 0.98G/1.14G [00:13<00:02, 75.2MB/s]
# Downloading:  87%|████████▋ | 0.99G/1.14G [00:13<00:02, 74.9MB/s]
# Downloading:  87%|████████▋ | 1.00G/1.14G [00:13<00:02, 74.9MB/s]
# Downloading:  88%|████████▊ | 1.00G/1.14G [00:13<00:01, 76.1MB/s]
# Downloading:  89%|████████▊ | 1.01G/1.14G [00:13<00:01, 76.3MB/s]
# Downloading:  89%|████████▉ | 1.02G/1.14G [00:13<00:01, 74.4MB/s]
# Downloading:  90%|████████▉ | 1.02G/1.14G [00:13<00:01, 73.8MB/s]
# Downloading:  91%|█████████ | 1.03G/1.14G [00:13<00:01, 75.6MB/s]
# Downloading:  91%|█████████▏| 1.04G/1.14G [00:13<00:01, 77.3MB/s]
# Downloading:  92%|█████████▏| 1.05G/1.14G [00:14<00:01, 64.0MB/s]
# Downloading:  92%|█████████▏| 1.05G/1.14G [00:14<00:01, 63.3MB/s]
# Downloading:  93%|█████████▎| 1.06G/1.14G [00:14<00:01, 63.2MB/s]
# Downloading:  94%|█████████▎| 1.07G/1.14G [00:14<00:01, 63.3MB/s]
# Downloading:  94%|█████████▍| 1.07G/1.14G [00:14<00:01, 64.9MB/s]
# Downloading:  95%|█████████▍| 1.08G/1.14G [00:14<00:00, 66.8MB/s]
# Downloading:  95%|█████████▌| 1.09G/1.14G [00:14<00:00, 70.0MB/s]
# Downloading:  96%|█████████▌| 1.09G/1.14G [00:14<00:00, 69.8MB/s]
# Downloading:  97%|█████████▋| 1.10G/1.14G [00:14<00:00, 72.9MB/s]
# Downloading:  97%|█████████▋| 1.11G/1.14G [00:14<00:00, 71.7MB/s]
# Downloading:  98%|█████████▊| 1.11G/1.14G [00:15<00:00, 76.1MB/s]
# Downloading:  99%|█████████▊| 1.12G/1.14G [00:15<00:00, 67.3MB/s]
# Downloading:  99%|█████████▉| 1.13G/1.14G [00:15<00:00, 69.0MB/s]
# Downloading: 100%|█████████▉| 1.14G/1.14G [00:15<00:00, 72.1MB/s]
# Downloading: 100%|██████████| 1.14G/1.14G [00:15<00:00, 79.0MB/s]
# Downloading:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# Downloading: 100%|██████████| 26.0/26.0 [00:00<00:00, 33.2kB/s]
# Downloading:   0%|          | 0.00/878k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 878k/878k [00:00<00:00, 69.6MB/s]
# Downloading:   0%|          | 0.00/446k [00:00<?, ?B/s]
# Downloading: 100%|██████████| 446k/446k [00:00<00:00, 66.7MB/s]
# Cloning https://huggingface.co/romainlhardy/distilbart-cnn-12-6-booksum into local empty directory.
# 2022-07-04 21:29:05,887 - huggingface_hub.repository - WARNING - Cloning https://huggingface.co/romainlhardy/distilbart-cnn-12-6-booksum into local empty directory.
# 2022-07-04 21:29:10,066 - __main__ - INFO - Fine-tuning the model...
# /opt/conda/lib/python3.8/site-packages/transformers/optimization.py:306: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# ***** Running training *****
#   Num examples = 116909
# ***** Running training *****
#   Num examples = 116909
# Num Epochs = 2
#   Instantaneous batch size per device = 4
# Num Epochs = 2
#   Instantaneous batch size per device = 4
# Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 58456
# Total train batch size (w. parallel, distributed & accumulation) = 4
#   Gradient Accumulation steps = 1
#   Total optimization steps = 58456
# 0%|          | 0/58456 [00:00<?, ?it/s]
# [2022-07-04 21:29:10.447 algo-1:34 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220512-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# /opt/conda/lib/python3.8/site-packages/smdebug-1.0.13b20220512-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [2022-07-04 21:29:10.642 algo-1:34 INFO profiler_config_parser.py:111] User has disabled profiler.
# [2022-07-04 21:29:10.643 algo-1:34 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [2022-07-04 21:29:10.644 algo-1:34 INFO hook.py:201] tensorboard_dir has not been set for the hook. SMDebug will not be exporting tensorboard summaries.
# [2022-07-04 21:29:10.644 algo-1:34 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [2022-07-04 21:29:10.644 algo-1:34 INFO state_store.py:77] The checkpoint config file /opt/ml/input/config/checkpointconfig.json does not exist.
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.shared.weight count_params:51470336
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.embed_positions.weight count_params:1050624
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.368 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.fc1.bias count_params:4096
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.fc2.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.0.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.fc1.bias count_params:4096
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.fc2.bias count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.369 algo-1:34 INFO hook.py:560] name:model.encoder.layers.1.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.fc1.bias count_params:4096
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.fc2.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.2.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.370 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.fc1.bias count_params:4096
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.fc2.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.3.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.371 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.fc1.bias count_params:4096
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.fc2.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.4.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.fc1.bias count_params:4096
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.fc2.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.5.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.372 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.fc1.bias count_params:4096
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.fc2.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.6.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.373 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.fc1.bias count_params:4096
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.fc2.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.7.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.374 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.fc1.bias count_params:4096
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.fc2.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.8.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.fc1.bias count_params:4096
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.fc2.bias count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.375 algo-1:34 INFO hook.py:560] name:model.encoder.layers.9.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.fc1.bias count_params:4096
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.fc2.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.10.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.376 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.fc1.bias count_params:4096
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.fc2.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layers.11.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layernorm_embedding.weight count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.encoder.layernorm_embedding.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.embed_positions.weight count_params:1050624
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.self_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.377 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.v_proj.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.q_proj.weight count_params:1048576
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.q_proj.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.out_proj.weight count_params:1048576
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn.out_proj.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.encoder_attn_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.fc1.weight count_params:4194304
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.fc1.bias count_params:4096
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.fc2.weight count_params:4194304
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.fc2.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.final_layer_norm.weight count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.0.final_layer_norm.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.1.self_attn.k_proj.weight count_params:1048576
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.1.self_attn.k_proj.bias count_params:1024
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.1.self_attn.v_proj.weight count_params:1048576
# [2022-07-04 21:29:11.378 algo-1:34 INFO hook.py:560] name:model.decoder.layers.1.self_attn.v_proj.bias count_params:1024
# ...
# 47%|████▋     | 27741/58456 [3:02:47<2:28:29,  3.45it/s]
# 47%|████▋     | 27742/58456 [3:02:47<2:11:24,  3.90it/s]
# 47%|████▋     | 27743/58456 [3:02:47<1:59:29,  4.28it/s]
# 47%|████▋     | 27744/58456 [3:02:47<1:47:26,  4.76it/s]
# 47%|████▋     | 27745/58456 [3:02:47<1:40:40,  5.08it/s]
# 47%|████▋     | 27746/58456 [3:02:48<1:47:13,  4.77it/s]
# 47%|████▋     | 27747/58456 [3:02:48<1:48:39,  4.71it/s]
# 47%|████▋     | 27748/58456 [3:02:48<1:48:51,  4.70it/s]
# 48%|████▊     | 27983/58456 [3:03:38<1:40:54,  5.03it/s]
# 48%|████▊     | 27984/58456 [3:03:38<1:35:57,  5.29it/s]
# 48%|████▊     | 27985/58456 [3:03:38<1:31:39,  5.54it/s]
# 48%|████▊     | 27986/58456 [3:03:38<1:27:52,  5.78it/s]
# 48%|████▊     | 27987/58456 [3:03:38<1:27:48,  5.78it/s]
# 48%|████▊     | 27988/58456 [3:03:39<1:27:49,  5.78it/s]
# 48%|████▊     | 27989/58456 [3:03:39<1:29:23,  5.68it/s]
# 48%|████▊     | 27990/58456 [3:03:39<1:35:21,  5.32it/s]
# 48%|████▊     | 27991/58456 [3:03:39<1:36:41,  5.25it/s]
# 48%|████▊     | 27992/58456 [3:03:40<1:46:24,  4.77it/s]
# 48%|████▊     | 27993/58456 [3:03:40<1:42:34,  4.95it/s]
# 48%|████▊     | 27994/58456 [3:03:40<1:46:24,  4.77it/s]
# 48%|████▊     | 27995/58456 [3:03:40<2:17:42,  3.69it/s]
# 48%|████▊     | 27996/58456 [3:03:40<1:59:37,  4.24it/s]
# 48%|████▊     | 27997/58456 [3:03:41<1:49:31,  4.63it/s]
# 48%|████▊     | 27998/58456 [3:03:41<1:46:46,  4.75it/s]
# 48%|████▊     | 27999/58456 [3:03:41<1:41:27,  5.00it/s]
# 48%|████▊     | 28000/58456 [3:03:41<1:48:42,  4.67it/s]
# {'loss': 2.8979, 'learning_rate': 1.0510042100904134e-05, 'epoch': 0.96}
# 48%|████▊     | 28000/58456 [3:03:41<1:48:42,  4.67it/s]
# Saving model checkpoint to /opt/ml/model/checkpoint-28000
# Saving model checkpoint to /opt/ml/model/checkpoint-28000
# Configuration saved in /opt/ml/model/checkpoint-28000/config.json
# Configuration saved in /opt/ml/model/checkpoint-28000/config.json
# Model weights saved in /opt/ml/model/checkpoint-28000/pytorch_model.bin
# Model weights saved in /opt/ml/model/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in /opt/ml/model/checkpoint-28000/tokenizer_config.json
# tokenizer config file saved in /opt/ml/model/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/checkpoint-28000/special_tokens_map.json
# Special tokens file saved in /opt/ml/model/checkpoint-28000/special_tokens_map.json
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# tokenizer config file saved in /opt/ml/model/tokenizer_config.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json
# Special tokens file saved in /opt/ml/model/special_tokens_map.json

# %% [markdown]
# ### Estimator Parameters

# %%
print(f'Container image used for training job: \n{hf_estimator.image_uri}\n')
print(f'S3 URI where the trained model is located: \n{hf_estimator.model_data}\n')
print(f'Latest training job name for this estimator: \n{hf_estimator.latest_training_job.name}\n')
# Out:
# Container image used for training job:
# None
#
# S3 URI where the trained model is located:
# s3://sagemaker-us-east-1-583579242701/huggingface-pytorch-training-2022-07-04-21-22-16-684/output/model.tar.gz
#
# Latest training job name for this estimator:
# huggingface-pytorch-training-2022-07-04-21-22-16-684
